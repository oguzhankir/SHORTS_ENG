# %%
#!pip install pyautogui
import pyautogui as ag

# %%
ss = ag.screenshot()

ss.save('ss.jpg')

# %%
from PIL import Image
Image.open('ss.jpg')
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=1920x1080 at 0x280F05F3B50>
